# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/temp.admin/Documents/Stats AIDS/diabetes.csv")

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
selected_cols = ["Glucose","BloodPressure","BMI","Age"]
desc_stats = pd.DataFrame({
    'Mean' : df[selected_cols].mean(),
    'Median' : df[selected_cols].median(),
    'Mode' : df[selected_cols].mode().iloc[0],
    'Minimum' : df[selected_cols].min(),
    'Maximum' : df[selected_cols].max(),
    'Variance' : df[selected_cols].var(),
    'Standard Deviation' : df[selected_cols].std()
})
pd.set_option('display.width',1000)
print(desc_stats.round(2))
# Out:
#                  Mean  Median  Mode  Minimum  Maximum  Variance  Standard Deviation
# Glucose        120.89   117.0  99.0      0.0    199.0   1022.25               31.97
# BloodPressure   69.11    72.0  70.0      0.0    122.0    374.65               19.36
# BMI             31.99    32.0  32.0      0.0     67.1     62.16                7.88
# Age             33.24    29.0  22.0     21.0     81.0    138.30               11.76

# %%
plt.figure(figsize = (15,10))

for i,col in enumerate(df.columns[:-1]):
    plt.subplot(2,4,i+1)
    sns.boxplot(y=df[col])
    plt.title(f"{col}")

plt.tight_layout()
plt.show()

# %%
df.hist(figsize = (11,9))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (5,3))
sns.countplot(x='Outcome', data = df)
plt.title("Diabetes Distribution")
plt.show()

# %%
sns.scatterplot(x="Glucose",y="BMI",hue="Outcome",data=df)
plt.title("Scatter Plot:Gluucose vs BMI")
plt.xlabel("Glucose")
plt.ylabel("BMI")
plt.show()

# %%
sns.scatterplot(x="Glucose",y="Age", hue="Outcome",data=df)
plt.title("Scatter Plot:Gluucose vs Age")
plt.xlabel("Glucose")
plt.ylabel("Age")
plt.show()

# %%
var=["Glucose","BMI","Age"]
sns.pairplot(data =df[var+["Outcome"]],vars=var,hue='Outcome')
plt.show()
